# %%
import pandas as pd
import bz2
import csv
import networkx as nx

from io import StringIO
from decimal import Decimal

filename = "data.everef.net/market-orders/history/2023/2023-01-01/market-orders-2023-01-01_00-15-03.v3.csv.bz2"

with bz2.open(filename, mode="r") as data_csv:
    contents = data_csv.read()

contents_f = StringIO(bytes.decode(contents, "utf-8"))

reader = csv.DictReader(contents_f)

# %%
type_id_to_buys_and_sells = {}

for row in reader:
    type_id = row["type_id"]
    if type_id not in type_id_to_buys_and_sells:
        buys_and_sells = {"buys":[], "sells":[]}
        type_id_to_buys_and_sells[type_id] = buys_and_sells
    else:
        buys_and_sells = type_id_to_buys_and_sells[type_id]
    
    if row["is_buy_order"] == 'true':
        buys_and_sells["buys"].append(row)
    else:
        buys_and_sells["sells"].append(row)
        
arbitrages = []
        
for type_id, buys_and_sells in type_id_to_buys_and_sells.items():
    for buy in buys_and_sells["buys"]:
        for sell in buys_and_sells["sells"]:
            # conditions for valid arbitrage:
            # 1. sell order lower than buy order
            # (i.e. we buy from the sell order low, and sell into the buy order high)
            # 2. sell volume remain is higher than buy min_volume
    
            # TODO: smarter, non O(n^2) way to do this
            sell_price = Decimal(sell["price"])
            buy_price = Decimal(buy["price"])
            
            if sell_price < buy_price and int(sell["volume_remain"]) > int(buy["min_volume"]):
                # arbitrage found!
                arbitrages.append((sell, buy))

# %%
len(arbitrages)
# Out:
# 1817195

# %%
def arbitrage_stats(arbitrage):
    wallet_amount = 20_000_000

    max_quantity = min(int(arbitrage[0]["volume_remain"]), int(arbitrage[1]["volume_remain"]))
    sell_price = float(arbitrage[0]["price"])
    buy_price = float(arbitrage[1]["price"])
    
    # you can only invest as much as you can afford
    quantity = min(max_quantity, wallet_amount/sell_price)
    real_investment = sell_price * quantity
    profit = quantity * (buy_price - sell_price)
    total_return = 100 * profit/real_investment
    
    # If you have money in your wallet you can't invest because the opportunity is too small
    # then it's like you did invest it, but with no return.
    # The return considering ALL the money we had available may be much, much lower.
    # This captures the idea that there's no point pursuing opportunities to make 600% on like $5
    adj_return = 100 * profit/wallet_amount
    
    # TODO: this considers each investment to take the same amount of time, which isn't true
    # We should be calculating the return per jump (with compounding).
    # We definitely need to filter out completely SHIT investments that wouldn't even be worth
    # doing if they took only one jump.
    
    return {
        "total_return": total_return,
        "adj_return": adj_return,
        "type_id": arbitrage[0]["type_id"],
        "from_system":arbitrage[0]["system_id"],
        "to_system":arbitrage[1]["system_id"],
        "real_investment": real_investment,
        "profit": profit
    }

# %%
arb_stats = sorted([arbitrage_stats(arb) for arb in arbitrages], key=lambda arb: arb["adj_return"], reverse=True)
arb_stats
# Out:
# [{'total_return': 4225.714285714285,
#   'adj_return': 1120.37208,
#   'type_id': '1824',
#   'from_system': '30004967',
#   'to_system': '30002187',
#   'real_investment': 5302640.0,
#   'profit': 224074416.0},
#  {'total_return': 3937.3333333333335,
#   'adj_return': 1118.47828,
#   'type_id': '1824',
#   'from_system': '30002803',
#   'to_system': '30002187',
#   'real_investment': 5681400.0,
#   'profit': 223695656.0},
#  {'total_return': 3340.1272438082256,
#   'adj_return': 1113.5468248,
#   'type_id': '1824',
#   'from_system': '30003327',
#   'to_system': '30002187',
#   'real_investment': 6667691.04,
#   'profit': 222709364.96},
#  {'total_return': 3087.032943900642,
#   'adj_return': 1110.8992924,
#   'type_id': '1824',
#   'from_system': '30003018',
#   'to_system': '30002187',
#   'real_investment': 7197197.5200000005,
#   'profit': 222179858.48},
#  {'total_return': 3070.6806282722514,
#   'adj_return': 1110.7137,
#   'type_id': '1824',
#   'from_system': '30002801',
#   'to_system': '30002187',
#   'real_investment': 7234316.0,
#   'profit': 222142740.0},
#  {'total_return': 2756.603773584906,
#   'adj_return': 1106.73672,
#   'type_id': '1824',
#   'from_system': '30000160',
#   'to_system': '30002187',
#   'real_investment': 8029712.0,
#   'profit': 221347344.0},
#  {'total_return': 2247.2868217054265,
#   'adj_return': 1098.02524,
#   'type_id': '1824',
#   'from_system': '30003577',
#   'to_system': '30002187',
#   'real_investment': 9772008.0,
#   'profit': 219605048.0},
#  {'total_return': 2229.230769230769,
#   'adj_return': 1097.64648,
#   'type_id': '1824',
#   'from_system': '30001403',
#   'to_system': '30002187',
#   'real_investment': 9847760.0,
#   'profit': 219529296.0},
#  {'total_return': 2229.230769230769,
#   'adj_return': 1097.64648,
#   'type_id': '1824',
#   'from_system': '30001425',
#   'to_system': '30002187',
#   'real_investment': 9847760.0,
#   'profit': 219529296.0},
#  {'total_return': 1945.945945945946,
#   'adj_return': 1090.8288,
#   'type_id': '1824',
#   'from_system': '30003522',
#   'to_system': '30002187',
#   'real_investment': 11211296.0,
#   'profit': 218165760.0},
#  {'total_return': 1945.945945945946,
#   'adj_return': 1090.8288,
#   'type_id': '1824',
#   'from_system': '30003563',
#   'to_system': '30002187',
#   'real_investment': 11211296.0,
#   'profit': 218165760.0},
#  {'total_return': 1925.4180602006688,
#   'adj_return': 1090.26066,
#   'type_id': '1824',
#   'from_system': '30000142',
#   'to_system': '30002187',
#   'real_investment': 11324924.0,
#   'profit': 218052132.0},
#  {'total_return': 1924.0641711229948,
#   'adj_return': 1090.222784,
#   'type_id': '1824',
#   'from_system': '30000142',
#   'to_system': '30002187',
#   'real_investment': 11332499.2,
#   'profit': 218044556.8},
#  {'total_return': 1922.712090848364,
#   'adj_return': 1090.1849080000002,
#   'type_id': '1824',
#   'from_system': '30000142',
#   'to_system': '30002187',
#   'real_investment': 11340074.399999999,
#   'profit': 218036981.60000002},
#  {'total_return': 1920.013342228152,
#   'adj_return': 1090.109156,
#   'type_id': '1824',
#   'from_system': '30042715',
#   'to_system': '30002187',
#   'real_investment': 11355224.8,
#   'profit': 218021831.2},
#  {'total_return': 1650.2890173410406,
#   'adj_return': 1010.67,
#   'type_id': '1824',
#   'from_system': '30002505',
#   'to_system': '30002187',
#   'real_investment': 12248400.0,
#   'profit': 202134000.0},
#  {'total_return': 1399.009900990099,
#   'adj_return': 937.55376,
#   'type_id': '1824',
#   'from_system': '30002659',
#   'to_system': '30002187',
#   'real_investment': 13403104.0,
#   'profit': 187510752.0},
#  {'total_return': 2227.4404304381246,
#   'adj_return': 664.836218,
#   'type_id': '1824',
#   'from_system': '30045344',
#   'to_system': '30002187',
#   'real_investment': 5969508.399999999,
#   'profit': 132967243.60000001},
#  {'total_return': 2701.1100832562443,
#   'adj_return': 613.179,
#   'type_id': '1824',
#   'from_system': '30003570',
#   'to_system': '30002187',
#   'real_investment': 4540200.0,
#   'profit': 122635800.0},
#  {'total_return': 1793.6835522201375,
#   'adj_return': 597.683359,
#   'type_id': '1824',
#   'from_system': '30002659',
#   'to_system': '30002187',
#   'real_investment': 6664312.2,
#   'profit': 119536671.8},
#  {'total_return': 1403.475670307845,
#   'adj_return': 584.597412,
#   'type_id': '1824',
#   'from_system': '30002659',
#   'to_system': '30002187',
#   'real_investment': 8330709.600000001,
#   'profit': 116919482.39999999},
#  {'total_return': 484.6666666666667,
#   'adj_return': 484.6666666666667,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 96933333.33333334},
#  {'total_return': 484.33333333333337,
#   'adj_return': 484.33333333333337,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 96866666.66666667},
#  {'total_return': 483.33333333333337,
#   'adj_return': 483.33333333333337,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 96666666.66666667},
#  {'total_return': 454.7158403869408,
#   'adj_return': 454.7158403869408,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005199',
#   'real_investment': 20000000.0,
#   'profit': 90943168.07738815},
#  {'total_return': 450.6650544135429,
#   'adj_return': 450.6650544135429,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 90133010.8827086},
#  {'total_return': 450.60459492140274,
#   'adj_return': 450.60459492140274,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 90120918.98428054},
#  {'total_return': 448.9721886336155,
#   'adj_return': 448.9721886336155,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 89794437.7267231},
#  {'total_return': 448.7908101571947,
#   'adj_return': 448.7908101571947,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 89758162.03143895},
#  {'total_return': 445.3446191051996,
#   'adj_return': 445.3446191051996,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 89068923.82103992},
#  {'total_return': 444.25634824667475,
#   'adj_return': 444.25634824667475,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 88851269.64933495},
#  {'total_return': 441.77750906892385,
#   'adj_return': 441.77750906892385,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 88355501.81378476},
#  {'total_return': 438.33131801692866,
#   'adj_return': 438.33131801692866,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 87666263.60338573},
#  {'total_return': 433.7363966142685,
#   'adj_return': 433.7363966142685,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 86747279.3228537},
#  {'total_return': 433.4340991535671,
#   'adj_return': 433.4340991535671,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86686819.83071342},
#  {'total_return': 433.3131801692865,
#   'adj_return': 433.3131801692865,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86662636.03385732},
#  {'total_return': 433.2527206771463,
#   'adj_return': 433.2527206771463,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86650544.13542926},
#  {'total_return': 433.01088270858526,
#   'adj_return': 433.01088270858526,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86602176.54171705},
#  {'total_return': 433.01088270858526,
#   'adj_return': 433.01088270858526,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86602176.54171705},
#  {'total_return': 432.8899637243048,
#   'adj_return': 432.8899637243048,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86577992.74486095},
#  {'total_return': 432.6481257557437,
#   'adj_return': 432.6481257557437,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86529625.15114874},
#  {'total_return': 429.74607013301085,
#   'adj_return': 429.74607013301085,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 85949214.02660218},
#  {'total_return': 426.2998790810157,
#   'adj_return': 426.2998790810157,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 85259975.81620315},
#  {'total_return': 426.2394195888755,
#   'adj_return': 426.2394195888755,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 85247883.9177751},
#  {'total_return': 423.3373639661427,
#   'adj_return': 423.3373639661427,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 84667472.79322854},
#  {'total_return': 423.0955259975816,
#   'adj_return': 423.0955259975816,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 84619105.19951633},
#  {'total_return': 417.0495767835551,
#   'adj_return': 417.0495767835551,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002526',
#   'real_investment': 20000000.0,
#   'profit': 83409915.35671102},
#  {'total_return': 415.84038694074974,
#   'adj_return': 415.84038694074974,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 83168077.38814995},
#  {'total_return': 414.5707376058041,
#   'adj_return': 414.5707376058041,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30004759',
#   'real_investment': 20000000.0,
#   'profit': 82914147.52116083},
#  {'total_return': 414.0,
#   'adj_return': 414.0,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 82800000.0},
#  {'total_return': 413.9056831922612,
#   'adj_return': 413.9056831922612,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001401',
#   'real_investment': 20000000.0,
#   'profit': 82781136.63845225},
#  {'total_return': 408.5247883917775,
#   'adj_return': 408.5247883917775,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 81704957.6783555},
#  {'total_return': 408.403869407497,
#   'adj_return': 408.403869407497,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 81680773.8814994},
#  {'total_return': 407.1946795646917,
#   'adj_return': 407.1946795646917,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 81438935.91293834},
#  {'total_return': 406.8923821039903,
#   'adj_return': 406.8923821039903,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002526',
#   'real_investment': 20000000.0,
#   'profit': 81378476.42079806},
#  {'total_return': 406.590084643289,
#   'adj_return': 406.590084643289,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002537',
#   'real_investment': 20000000.0,
#   'profit': 81318016.9286578},
#  {'total_return': 404.9576783555018,
#   'adj_return': 404.9576783555018,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 80991535.67110036},
#  {'total_return': 404.23216444981864,
#   'adj_return': 404.23216444981864,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 80846432.88996373},
#  {'total_return': 402.59975816203143,
#   'adj_return': 402.59975816203143,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 80519951.6324063},
#  {'total_return': 402.5392986698912,
#   'adj_return': 402.5392986698912,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 80507859.73397824},
#  {'total_return': 400.12091898428054,
#   'adj_return': 400.12091898428054,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 80024183.7968561},
#  {'total_return': 398.91172914147523,
#   'adj_return': 398.91172914147523,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 79782345.82829505},
#  {'total_return': 397.64207980652964,
#   'adj_return': 397.64207980652964,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30004759',
#   'real_investment': 20000000.0,
#   'profit': 79528415.96130593},
#  {'total_return': 393.47037484885124,
#   'adj_return': 393.47037484885124,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 78694074.96977025},
#  {'total_return': 386.7593712212817,
#   'adj_return': 386.7593712212817,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 20000000.0,
#   'profit': 77351874.24425635},
#  {'total_return': 385.006045949214,
#   'adj_return': 385.006045949214,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 20000000.0,
#   'profit': 77001209.1898428},
#  {'total_return': 383.49455864570734,
#   'adj_return': 383.49455864570734,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 76698911.72914147},
#  {'total_return': 450.78597339782345,
#   'adj_return': 383.2384,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 17003120.0,
#   'profit': 76647680.0},
#  {'total_return': 379.9274486094317,
#   'adj_return': 379.9274486094317,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 75985489.72188634},
#  {'total_return': 377.6299879081016,
#   'adj_return': 377.6299879081016,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000240',
#   'real_investment': 20000000.0,
#   'profit': 75525997.58162032},
#  {'total_return': 377.44860943168084,
#   'adj_return': 377.44860943168084,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002537',
#   'real_investment': 20000000.0,
#   'profit': 75489721.88633616},
#  {'total_return': 438.2103990326481,
#   'adj_return': 375.8088,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002059',
#   'real_investment': 17151980.0,
#   'profit': 75161760.0},
#  {'total_return': 371.584038694075,
#   'adj_return': 371.584038694075,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002537',
#   'real_investment': 20000000.0,
#   'profit': 74316807.738815},
#  {'total_return': 448.24667472793226,
#   'adj_return': 370.7,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 16540000.0,
#   'profit': 74140000.0},
#  {'total_return': 368.56106408706165,
#   'adj_return': 368.56106408706165,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 73712212.81741233},
#  {'total_return': 433.4945586457074,
#   'adj_return': 368.538,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 17003120.0,
#   'profit': 73707600.0},
#  {'total_return': 445.4050785973398,
#   'adj_return': 368.35,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 73670000.0},
#  {'total_return': 442.92623941958885,
#   'adj_return': 365.5674,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 16506920.0,
#   'profit': 73113480.0},
#  {'total_return': 365.17533252720676,
#   'adj_return': 365.17533252720676,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 73035066.50544135},
#  {'total_return': 362.93833131801694,
#   'adj_return': 362.93833131801694,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003488',
#   'real_investment': 20000000.0,
#   'profit': 72587666.26360339},
#  {'total_return': 438.27085852478837,
#   'adj_return': 362.45,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 72490000.0},
#  {'total_return': 441.41475211608224,
#   'adj_return': 361.03445,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 16358060.0,
#   'profit': 72206890.0},
#  {'total_return': 358.1015719467957,
#   'adj_return': 358.1015719467957,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 71620314.38935913},
#  {'total_return': 432.04353083434097,
#   'adj_return': 357.3,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 16540000.0,
#   'profit': 71460000.0},
#  {'total_return': 429.86698911729144,
#   'adj_return': 354.789,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 16506920.0,
#   'profit': 70957800.0},
#  {'total_return': 427.62998790810155,
#   'adj_return': 353.65,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 16540000.0,
#   'profit': 70730000.0},
#  {'total_return': 353.4461910519952,
#   'adj_return': 353.4461910519952,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001115',
#   'real_investment': 20000000.0,
#   'profit': 70689238.21039903},
#  {'total_return': 426.360338573156,
#   'adj_return': 352.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 70520000.0},
#  {'total_return': 352.17654171704964,
#   'adj_return': 352.17654171704964,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 70435308.34340993},
#  {'total_return': 351.0278113663845,
#   'adj_return': 351.0278113663845,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 70205562.27327691},
#  {'total_return': 429.62515114873037,
#   'adj_return': 347.4834,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 16176120.0,
#   'profit': 69496680.0},
#  {'total_return': 345.0,
#   'adj_return': 345.0,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 69000000.0},
#  {'total_return': 416.8681983071342,
#   'adj_return': 344.75,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 68950000.0},
#  {'total_return': 414.3893591293833,
#   'adj_return': 342.7,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30004759',
#   'real_investment': 16540000.0,
#   'profit': 68540000.0},
#  {'total_return': 341.41475211608224,
#   'adj_return': 341.41475211608224,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 68282950.42321645},
#  {'total_return': 341.354292623942,
#   'adj_return': 341.354292623942,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003388',
#   'real_investment': 20000000.0,
#   'profit': 68270858.5247884},
#  {'total_return': 407.01330108827085,
#   'adj_return': 336.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002510',
#   'real_investment': 16540000.0,
#   'profit': 67320000.0},
#  {'total_return': 335.8524788391778,
#   'adj_return': 335.8524788391778,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30022547',
#   'real_investment': 20000000.0,
#   'profit': 67170495.76783556},
#  {'total_return': 335.3083434099154,
#   'adj_return': 335.3083434099154,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002320',
#   'real_investment': 20000000.0,
#   'profit': 67061668.681983076},
#  {'total_return': 404.83675937122126,
#   'adj_return': 334.8,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 16540000.0,
#   'profit': 66960000.0},
#  {'total_return': 401.69286577992744,
#   'adj_return': 332.2,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 66440000.0},
#  {'total_return': 441.35429262394194,
#   'adj_return': 328.135,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 14869460.0,
#   'profit': 65627000.0},
#  {'total_return': 327.33333333333337,
#   'adj_return': 327.33333333333337,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 65466666.66666667},
#  {'total_return': 442.98669891172915,
#   'adj_return': 327.15055,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 14770220.0,
#   'profit': 65430110.0},
#  {'total_return': 350.0,
#   'adj_return': 326.151,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30005060',
#   'real_investment': 18637200.0,
#   'profit': 65230200.0},
#  {'total_return': 392.98669891172915,
#   'adj_return': 325.0,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 65000000.0},
#  {'total_return': 324.7279322853688,
#   'adj_return': 324.7279322853688,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005230',
#   'real_investment': 20000000.0,
#   'profit': 64945586.45707376},
#  {'total_return': 323.21644498186214,
#   'adj_return': 323.21644498186214,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002138',
#   'real_investment': 20000000.0,
#   'profit': 64643288.99637243},
#  {'total_return': 323.21644498186214,
#   'adj_return': 323.21644498186214,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 64643288.99637243},
#  {'total_return': 386.69891172914146,
#   'adj_return': 319.8,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 16540000.0,
#   'profit': 63960000.0},
#  {'total_return': 381.6203143893591,
#   'adj_return': 315.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 63120000.0},
#  {'total_return': 378.89963724304715,
#   'adj_return': 313.35,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 16540000.0,
#   'profit': 62670000.0},
#  {'total_return': 448.48851269649333,
#   'adj_return': 309.7015,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 13810900.0,
#   'profit': 61940300.0},
#  {'total_return': 467.3333333333333,
#   'adj_return': 307.3885,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 13155000.0,
#   'profit': 61477700.0},
#  {'total_return': 432.34582829504234,
#   'adj_return': 304.6326,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 14092080.0,
#   'profit': 60926520.0},
#  {'total_return': 300.0,
#   'adj_return': 300.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 60000000.0},
#  {'total_return': 300.0,
#   'adj_return': 300.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003574',
#   'real_investment': 20000000.0,
#   'profit': 60000000.0},
#  {'total_return': 340.0,
#   'adj_return': 297.5,
#   'type_id': '649',
#   'from_system': '30003416',
#   'to_system': '30001868',
#   'real_investment': 17500000.0,
#   'profit': 59500000.0},
#  {'total_return': 296.0701330108828,
#   'adj_return': 296.0701330108828,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000843',
#   'real_investment': 20000000.0,
#   'profit': 59214026.60217655},
#  {'total_return': 414.20798065296253,
#   'adj_return': 294.93555,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000240',
#   'real_investment': 14240940.0,
#   'profit': 58987110.0},
#  {'total_return': 292.98669891172915,
#   'adj_return': 292.98669891172915,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001274',
#   'real_investment': 20000000.0,
#   'profit': 58597339.78234583},
#  {'total_return': 351.8742442563482,
#   'adj_return': 291.0,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 16540000.0,
#   'profit': 58200000.0},
#  {'total_return': 349.57678355501815,
#   'adj_return': 289.1,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 16540000.0,
#   'profit': 57820000.0},
#  {'total_return': 341.41475211608224,
#   'adj_return': 282.35,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003409',
#   'real_investment': 16540000.0,
#   'profit': 56470000.0},
#  {'total_return': 401.813784764208,
#   'adj_return': 280.7935,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002996',
#   'real_investment': 13976300.0,
#   'profit': 56158700.0},
#  {'total_return': 280.0,
#   'adj_return': 280.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 56000000.0},
#  {'total_return': 338.3917775090689,
#   'adj_return': 279.85,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 16540000.0,
#   'profit': 55970000.0},
#  {'total_return': 279.0,
#   'adj_return': 279.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 55800000.0},
#  {'total_return': 278.75,
#   'adj_return': 278.75,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 55750000.0},
#  {'total_return': 278.5,
#   'adj_return': 278.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 55700000.0},
#  {'total_return': 335.79201934703747,
#   'adj_return': 277.7,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002510',
#   'real_investment': 16540000.0,
#   'profit': 55540000.0},
#  {'total_return': 372.67230955259976,
#   'adj_return': 277.0718,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 14869460.0,
#   'profit': 55414360.0},
#  {'total_return': 275.0,
#   'adj_return': 275.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003744',
#   'real_investment': 20000000.0,
#   'profit': 55000000.0},
#  {'total_return': 432.10399032648127,
#   'adj_return': 274.80215,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 12719260.0,
#   'profit': 54960430.0},
#  {'total_return': 348.24667472793226,
#   'adj_return': 273.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 15713000.0,
#   'profit': 54720000.0},
#  {'total_return': 400.06045949214024,
#   'adj_return': 272.28955,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 13612420.0,
#   'profit': 54457910.0},
#  {'total_return': 365.9613059250302,
#   'adj_return': 269.66115,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 14737140.0,
#   'profit': 53932230.0},
#  {'total_return': 268.8029020556228,
#   'adj_return': 268.8029020556228,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005308',
#   'real_investment': 20000000.0,
#   'profit': 53760580.41112455},
#  {'total_return': 267.89297658862876,
#   'adj_return': 267.89297658862876,
#   'type_id': '649',
#   'from_system': '30005310',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 53578595.317725755},
#  {'total_return': 323.21644498186214,
#   'adj_return': 267.3,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 53460000.0},
#  {'total_return': 266.78892964321443,
#   'adj_return': 266.78892964321443,
#   'type_id': '649',
#   'from_system': '30045305',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 53357785.928642884},
#  {'total_return': 266.14268440145105,
#   'adj_return': 266.14268440145105,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 53228536.88029021},
#  {'total_return': 266.0217654171705,
#   'adj_return': 266.0217654171705,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 53204353.083434105},
#  {'total_return': 265.9008464328899,
#   'adj_return': 265.9008464328899,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 53180169.28657799},
#  {'total_return': 262.5,
#   'adj_return': 262.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002507',
#   'real_investment': 20000000.0,
#   'profit': 52500000.0},
#  {'total_return': 445.82829504232166,
#   'adj_return': 258.09,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 11578000.0,
#   'profit': 51618000.0},
#  {'total_return': 257.99999999999994,
#   'adj_return': 257.99999999999994,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 51599999.99999999},
#  {'total_return': 257.75,
#   'adj_return': 257.75,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 51550000.0},
#  {'total_return': 257.5,
#   'adj_return': 257.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 51500000.0},
#  {'total_return': 257.00000000000006,
#   'adj_return': 257.00000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 51400000.00000001},
#  {'total_return': 257.00000000000006,
#   'adj_return': 257.00000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 51400000.00000001},
#  {'total_return': 256.50623885918003,
#   'adj_return': 256.50623885918003,
#   'type_id': '2679',
#   'from_system': '30002187',
#   'to_system': '30004504',
#   'real_investment': 20000000.0,
#   'profit': 51301247.771836005},
#  {'total_return': 309.6735187424426,
#   'adj_return': 256.1,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 16540000.0,
#   'profit': 51220000.0},
#  {'total_return': 255.0,
#   'adj_return': 255.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 51000000.0},
#  {'total_return': 254.83870967741933,
#   'adj_return': 254.83870967741933,
#   'type_id': '649',
#   'from_system': '30001382',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 50967741.935483865},
#  {'total_return': 252.5,
#   'adj_return': 252.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 50500000.0},
#  {'total_return': 250.7255139056832,
#   'adj_return': 250.7255139056832,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 50145102.78113664},
#  {'total_return': 250.0,
#   'adj_return': 250.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 50000000.0},
#  {'total_return': 250.0,
#   'adj_return': 250.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002661',
#   'real_investment': 20000000.0,
#   'profit': 50000000.0},
#  {'total_return': 249.2063492063492,
#   'adj_return': 249.2063492063492,
#   'type_id': '649',
#   'from_system': '30002765',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 49841269.841269836},
#  {'total_return': 249.09552523008566,
#   'adj_return': 249.09552523008566,
#   'type_id': '649',
#   'from_system': '30002751',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 49819105.04601713},
#  {'total_return': 471.42857142857144,
#   'adj_return': 247.17,
#   'type_id': '17429',
#   'from_system': '30003563',
#   'to_system': '30004472',
#   'real_investment': 10486000.0,
#   'profit': 49434000.0},
#  {'total_return': 245.25,
#   'adj_return': 245.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 49050000.0},
#  {'total_return': 279.24999999999994,
#   'adj_return': 245.20830799999996,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 17561920.0,
#   'profit': 49041661.599999994},
#  {'total_return': 244.80048367593713,
#   'adj_return': 244.80048367593713,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 48960096.735187426},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001366',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001368',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001376',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001393',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001426',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30002739',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0},
#  {'total_return': 243.5,
#   'adj_return': 243.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 48700000.0},
#  {'total_return': 292.98669891172915,
#   'adj_return': 242.3,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 48460000.0},
#  {'total_return': 242.00000000000006,
#   'adj_return': 242.00000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002661',
#   'real_investment': 20000000.0,
#   'profit': 48400000.00000001},
#  {'total_return': 238.25000000000006,
#   'adj_return': 238.25000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 47650000.00000001},
#  {'total_return': 237.83783783783784,
#   'adj_return': 237.83783783783784,
#   'type_id': '16272',
#   'from_system': '30000019',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 47567567.56756757},
#  {'total_return': 369.16565900846433,
#   'adj_return': 237.5234,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 12868120.0,
#   'profit': 47504680.0},
#  {'total_return': 253.69774919614147,
#   'adj_return': 236.7,
#   'type_id': '649',
#   'from_system': '30000139',
#   'to_system': '30001868',
#   'real_investment': 18660000.0,
#   'profit': 47340000.0},
#  {'total_return': 235.25,
#   'adj_return': 235.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 47050000.0},
#  {'total_return': 243.75,
#   'adj_return': 234.0,
#   'type_id': '649',
#   'from_system': '30002739',
#   'to_system': '30001868',
#   'real_investment': 19200000.0,
#   'profit': 46800000.0},
#  {'total_return': 233.61134278565473,
#   'adj_return': 233.61134278565473,
#   'type_id': '2679',
#   'from_system': '30002187',
#   'to_system': '30004504',
#   'real_investment': 20000000.0,
#   'profit': 46722268.55713095},
#  {'total_return': 233.4343740527433,
#   'adj_return': 233.4343740527433,
#   'type_id': '649',
#   'from_system': '30002764',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 46686874.810548656},
#  {'total_return': 233.33333333333334,
#   'adj_return': 233.33333333333334,
#   'type_id': '16272',
#   'from_system': '30000019',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 46666666.66666667},
#  {'total_return': 233.33333333333334,
#   'adj_return': 233.33333333333334,
#   'type_id': '16272',
#   'from_system': '30002391',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 46666666.66666667},
#  {'total_return': 233.33333333333334,
#   'adj_return': 233.33333333333334,
#   'type_id': '16272',
#   'from_system': '30003897',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 46666666.66666667},
#  {'total_return': 233.33333333333331,
#   'adj_return': 233.33333333333331,
#   'type_id': '2679',
#   'from_system': '30002187',
#   'to_system': '30004504',
#   'real_investment': 20000000.0,
#   'profit': 46666666.666666664},
#  {'total_return': 232.23333333333335,
#   'adj_return': 232.23333333333335,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 46446666.66666667},
#  {'total_return': 233.33333333333334,
#   'adj_return': 231.0,
#   'type_id': '649',
#   'from_system': '30005308',
#   'to_system': '30001868',
#   'real_investment': 19800000.0,
#   'profit': 46200000.0},
#  {'total_return': 230.49999999999994,
#   'adj_return': 230.49999999999994,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 46099999.99999999},
#  {'total_return': 225.0,
#   'adj_return': 225.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002526',
#   'real_investment': 20000000.0,
#   'profit': 45000000.0},
#  {'total_return': 9993.333333333334,
#   'adj_return': 224.85,
#   'type_id': '1824',
#   'from_system': '30005228',
#   'to_system': '30002187',
#   'real_investment': 450000.0,
#   'profit': 44970000.0},
#  {'total_return': 223.81513099793935,
#   'adj_return': 223.81513099793935,
#   'type_id': '649',
#   'from_system': '30000142',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44763026.19958787},
#  {'total_return': 223.52941176470588,
#   'adj_return': 223.52941176470588,
#   'type_id': '649',
#   'from_system': '30000153',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44705882.35294118},
#  {'total_return': 223.52941176470588,
#   'adj_return': 223.52941176470588,
#   'type_id': '649',
#   'from_system': '30004084',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44705882.35294118},
#  {'total_return': 340.0,
#   'adj_return': 222.938,
#   'type_id': '11289',
#   'from_system': '30045329',
#   'to_system': '30000142',
#   'real_investment': 13114000.0,
#   'profit': 44587600.0},
#  {'total_return': 222.5,
#   'adj_return': 222.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 44500000.0},
#  {'total_return': 383.6759371221282,
#   'adj_return': 222.11,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002665',
#   'real_investment': 11578000.0,
#   'profit': 44422000.0},
#  {'total_return': 445.6469165659008,
#   'adj_return': 221.13,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 9924000.0,
#   'profit': 44226000.0},
#  {'total_return': 220.60623724861554,
#   'adj_return': 220.60623724861554,
#   'type_id': '649',
#   'from_system': '30003327',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44121247.44972311},
#  {'total_return': 255.0,
#   'adj_return': 219.3,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 17200000.0,
#   'profit': 43860000.0},
#  {'total_return': 218.8405797101449,
#   'adj_return': 218.8405797101449,
#   'type_id': '649',
#   'from_system': '30000142',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 43768115.942028984},
#  {'total_return': 218.0,
#   'adj_return': 218.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 43600000.0},
#  {'total_return': 218.0,
#   'adj_return': 218.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 43600000.0},
#  {'total_return': 217.5,
#   'adj_return': 217.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000087',
#   'real_investment': 20000000.0,
#   'profit': 43500000.0},
#  {'total_return': 485.6666666666667,
#   'adj_return': 217.02015,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 8937000.0,
#   'profit': 43404030.0},
#  {'total_return': 216.25,
#   'adj_return': 216.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 43250000.0},
#  {'total_return': 214.2857142857143,
#   'adj_return': 214.2857142857143,
#   'type_id': '649',
#   'from_system': '30000142',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 42857142.85714286},
#  {'total_return': 213.75,
#   'adj_return': 213.75,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 42750000.0},
#  {'total_return': 348.24667472793226,
#   'adj_return': 213.696,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 12272680.0,
#   'profit': 42739200.0},
#  {'total_return': 212.5,
#   'adj_return': 212.5,
#   'type_id': '649',
#   'from_system': '30004973',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 42500000.0},
#  {'total_return': 212.5,
#   'adj_return': 212.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30005230',
#   'real_investment': 20000000.0,
#   'profit': 42500000.0},
#  {'total_return': 212.5,
#   'adj_return': 212.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30005292',
#   'real_investment': 20000000.0,
#   'profit': 42500000.0},
#  {'total_return': 212.25,
#   'adj_return': 212.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 42450000.0},
#  {'total_return': 210.0,
#   'adj_return': 210.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 42000000.0},
#  {'total_return': 422.97460701330107,
#   'adj_return': 209.88,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 9924000.0,
#   'profit': 41976000.0},
#  {'total_return': 268.98428053204356,
#   'adj_return': 208.88055,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001393',
#   'real_investment': 15531060.0,
#   'profit': 41776110.0},
#  {'total_return': 208.5,
#   'adj_return': 208.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 41700000.0},
#  {'total_return': 484.0,
#   'adj_return': 207.9264,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 8592000.0,
#   'profit': 41585280.0},
#  {'total_return': 223.88663967611336,
#   'adj_return': 207.375,
#   'type_id': '2679',
#   'from_system': '30003563',
#   'to_system': '30004504',
#   'real_investment': 18525000.0,
#   'profit': 41475000.0},
#  {'total_return': 268.8029020556227,
#   'adj_return': 206.9613,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000076',
#   'real_investment': 15398740.0,
#   'profit': 41392260.0},
#  {'total_return': 205.9118236472946,
#   'adj_return': 205.9118236472946,
#   'type_id': '16275',
#   'from_system': '30001015',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 41182364.72945892},
#  {'total_return': 205.811623246493,
#   'adj_return': 205.811623246493,
#   'type_id': '16275',
#   'from_system': '30001015',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 41162324.6492986},
#  {'total_return': 205.55555555555557,
#   'adj_return': 205.55555555555557,
#   'type_id': '649',
#   'from_system': '30000142',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 41111111.11111111},
#  {'total_return': 205.55555555555557,
#   'adj_return': 205.55555555555557,
#   'type_id': '649',
#   'from_system': '30004972',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 41111111.11111111},
#  {'total_return': 205.55555555555557,
#   'adj_return': 205.55555555555557,
#   'type_id': '649',
#   'from_system': '30014971',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 41111111.11111111},
#  {'total_return': 292.85714285714283,
#   'adj_return': 205.0,
#   'type_id': '649',
#   'from_system': '30003412',
#   'to_system': '30001868',
#   'real_investment': 14000000.0,
#   'profit': 41000000.0},
#  {'total_return': 204.98963035256804,
#   'adj_return': 204.98963035256804,
#   'type_id': '16272',
#   'from_system': '30004722',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 40997926.070513606},
#  {'total_return': 204.5404208194906,
#   'adj_return': 204.5404208194906,
#   'type_id': '649',
#   'from_system': '30004993',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 40908084.16389812},
#  {'total_return': 202.90581162324648,
#   'adj_return': 202.90581162324648,
#   'type_id': '16275',
#   'from_system': '30001015',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 40581162.3246493},
#  {'total_return': 202.69675288937808,
#   'adj_return': 202.69675288937808,
#   'type_id': '649',
#   'from_system': '30002659',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 40539350.577875614},
#  {'total_return': 201.3698630136986,
#   'adj_return': 201.3698630136986,
#   'type_id': '649',
#   'from_system': '30002659',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 40273972.60273972},
#  {'total_return': 200.75,
#   'adj_return': 200.75,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 40150000.0},
#  {'total_return': 200.60120240480964,
#   'adj_return': 200.60120240480964,
#   'type_id': '16275',
#   'from_system': '30001015',
#   'to_system': '30003794',
#   'real_investment': 20000000.0,
#   'profit': 40120240.48096193},
#  {'total_return': 200.54644808743166,
#   'adj_return': 200.54644808743166,
#   'type_id': '649',
#   'from_system': '30000142',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 40109289.617486335},
#  {'total_return': 200.25,
#   'adj_return': 200.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 40050000.0},
#  {'total_return': 200.05455537370432,
#   'adj_return': 200.05455537370432,
#   'type_id': '649',
#   'from_system': '30002386',
# ...
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30004967',
#   'real_investment': 20000000.0,
#   'profit': 21237113.402061857},
#  {'total_return': 106.18556701030928,
#   'adj_return': 106.18556701030928,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30004968',
#   'real_investment': 20000000.0,
#   'profit': 21237113.402061857},
#  {'total_return': 106.18556701030928,
#   'adj_return': 106.18556701030928,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30004973',
#   'real_investment': 20000000.0,
#   'profit': 21237113.402061857},
#  {'total_return': 106.00000000000003,
#   'adj_return': 106.00000000000003,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30002661',
#   'real_investment': 20000000.0,
#   'profit': 21200000.000000004},
#  {'total_return': 415.3431717029749,
#   'adj_return': 105.9870525,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5103589.5,
#   'profit': 21197410.5},
#  {'total_return': 105.77319587628868,
#   'adj_return': 105.77319587628868,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 21154639.175257735},
#  {'total_return': 409.25925925925924,
#   'adj_return': 105.6822,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5164560.0,
#   'profit': 21136440.0},
#  {'total_return': 408.31792975970427,
#   'adj_return': 105.63438,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5174124.0,
#   'profit': 21126876.0},
#  {'total_return': 408.2005082005082,
#   'adj_return': 105.6284025,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5175319.5,
#   'profit': 21125680.5},
#  {'total_return': 408.08314087759817,
#   'adj_return': 105.622425,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5176515.0,
#   'profit': 21124485.0},
#  {'total_return': 105.6,
#   'adj_return': 105.6,
#   'type_id': '17368',
#   'from_system': '30003563',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 21120000.0},
#  {'total_return': 105.56701030927837,
#   'adj_return': 105.56701030927837,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 21113402.061855674},
#  {'total_return': 168.25,
#   'adj_return': 105.5584348,
#   'type_id': '35',
#   'from_system': '30001858',
#   'to_system': '30000843',
#   'real_investment': 12547808.0,
#   'profit': 21111686.96},
#  {'total_return': 105.39152759948652,
#   'adj_return': 105.39152759948652,
#   'type_id': '655',
#   'from_system': '30002187',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 21078305.519897304},
#  {'total_return': 403.4324942791762,
#   'adj_return': 105.383325,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5224335.0,
#   'profit': 21076665.0},
#  {'total_return': 105.3776516686934,
#   'adj_return': 105.3776516686934,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 21075530.33373868},
#  {'total_return': 105.36082474226808,
#   'adj_return': 105.36082474226808,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 21072164.948453616},
#  {'total_return': 105.35989321285552,
#   'adj_return': 105.35989321285552,
#   'type_id': '20',
#   'from_system': '30000142',
#   'to_system': '30001847',
#   'real_investment': 20000000.0,
#   'profit': 21071978.642571103},
#  {'total_return': 105.3388090349076,
#   'adj_return': 105.3388090349076,
#   'type_id': '20',
#   'from_system': '30000142',
#   'to_system': '30001847',
#   'real_investment': 20000000.0,
#   'profit': 21067761.80698152},
#  {'total_return': 105.2,
#   'adj_return': 105.2,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30001392',
#   'real_investment': 20000000.0,
#   'profit': 21040000.0},
#  {'total_return': 105.12820512820514,
#   'adj_return': 105.12820512820514,
#   'type_id': '655',
#   'from_system': '30000190',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 21025641.025641028},
#  {'total_return': 105.12820512820514,
#   'adj_return': 105.12820512820514,
#   'type_id': '655',
#   'from_system': '30003018',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 21025641.025641028},
#  {'total_return': 105.12820512820514,
#   'adj_return': 105.12820512820514,
#   'type_id': '655',
#   'from_system': '30002187',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 21025641.025641028},
#  {'total_return': 105.12820512820514,
#   'adj_return': 105.12820512820514,
#   'type_id': '655',
#   'from_system': '30005308',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 21025641.025641028},
#  {'total_return': 233.370374486054,
#   'adj_return': 105.005,
#   'type_id': '17368',
#   'from_system': '30000019',
#   'to_system': '30002384',
#   'real_investment': 8999000.0,
#   'profit': 21001000.0},
#  {'total_return': 105.0,
#   'adj_return': 105.0,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30001399',
#   'real_investment': 20000000.0,
#   'profit': 21000000.0},
#  {'total_return': 233.33333333333334,
#   'adj_return': 105.0,
#   'type_id': '655',
#   'from_system': '30003368',
#   'to_system': '30003853',
#   'real_investment': 9000000.0,
#   'profit': 21000000.0},
#  {'total_return': 175.0,
#   'adj_return': 105.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002019',
#   'real_investment': 12000000.0,
#   'profit': 21000000.0},
#  {'total_return': 233.33333333333334,
#   'adj_return': 105.0,
#   'type_id': '17368',
#   'from_system': '30001425',
#   'to_system': '30002384',
#   'real_investment': 9000000.0,
#   'profit': 21000000.0},
#  {'total_return': 233.33333333333334,
#   'adj_return': 105.0,
#   'type_id': '17368',
#   'from_system': '30001425',
#   'to_system': '30002384',
#   'real_investment': 9000000.0,
#   'profit': 21000000.0},
#  {'total_return': 233.33333333333334,
#   'adj_return': 105.0,
#   'type_id': '17368',
#   'from_system': '30003471',
#   'to_system': '30002384',
#   'real_investment': 9000000.0,
#   'profit': 21000000.0},
#  {'total_return': 104.99999999999997,
#   'adj_return': 104.99999999999997,
#   'type_id': '34',
#   'from_system': '30001858',
#   'to_system': '30001038',
#   'real_investment': 20000000.0,
#   'profit': 20999999.999999996},
#  {'total_return': 104.97230104039991,
#   'adj_return': 104.97230104039991,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 20994460.208079983},
#  {'total_return': 104.83718416430209,
#   'adj_return': 104.83718416430209,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 20967436.832860418},
#  {'total_return': 104.8,
#   'adj_return': 104.8,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30000056',
#   'real_investment': 20000000.0,
#   'profit': 20960000.0},
#  {'total_return': 104.70206728820429,
#   'adj_return': 104.70206728820429,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 20940413.457640857},
#  {'total_return': 150.34770514603613,
#   'adj_return': 104.68176989999999,
#   'type_id': '35',
#   'from_system': '30000019',
#   'to_system': '30005008',
#   'real_investment': 13925290.020000001,
#   'profit': 20936353.979999997},
#  {'total_return': 388.8888888888889,
#   'adj_return': 104.60625,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5379750.0,
#   'profit': 20921250.0},
#  {'total_return': 104.57142857142856,
#   'adj_return': 104.57142857142856,
#   'type_id': '16273',
#   'from_system': '30000019',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 20914285.714285713},
#  {'total_return': 104.56695041210645,
#   'adj_return': 104.56695041210645,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 20913390.08242129},
#  {'total_return': 300.0,
#   'adj_return': 104.5545,
#   'type_id': '16272',
#   'from_system': '30003361',
#   'to_system': '30003093',
#   'real_investment': 6970300.0,
#   'profit': 20910900.0},
#  {'total_return': 300.0,
#   'adj_return': 104.5545,
#   'type_id': '16272',
#   'from_system': '30003361',
#   'to_system': '30003811',
#   'real_investment': 6970300.0,
#   'profit': 20910900.0},
#  {'total_return': 104.42857142857144,
#   'adj_return': 104.42857142857144,
#   'type_id': '16273',
#   'from_system': '30000019',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 20885714.285714287},
#  {'total_return': 104.32989690721651,
#   'adj_return': 104.32989690721651,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 20865979.381443303},
#  {'total_return': 166.25,
#   'adj_return': 104.303654,
#   'type_id': '35',
#   'from_system': '30001858',
#   'to_system': '30003697',
#   'real_investment': 12547808.0,
#   'profit': 20860730.8},
#  {'total_return': 108.9864158829676,
#   'adj_return': 104.3,
#   'type_id': '655',
#   'from_system': '30002637',
#   'to_system': '30003853',
#   'real_investment': 19140000.0,
#   'profit': 20860000.0},
#  {'total_return': 104.28571428571429,
#   'adj_return': 104.28571428571429,
#   'type_id': '16273',
#   'from_system': '30000019',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20857142.85714286},
#  {'total_return': 208.5,
#   'adj_return': 104.25,
#   'type_id': '11289',
#   'from_system': '30045329',
#   'to_system': '30000142',
#   'real_investment': 10000000.0,
#   'profit': 20850000.0},
#  {'total_return': 104.2,
#   'adj_return': 104.2,
#   'type_id': '44',
#   'from_system': '30001324',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20840000.0},
#  {'total_return': 104.15916816636673,
#   'adj_return': 104.15916816636673,
#   'type_id': '44',
#   'from_system': '30001277',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20831833.633273344},
#  {'total_return': 104.14412575278143,
#   'adj_return': 104.14412575278143,
#   'type_id': '20',
#   'from_system': '30002187',
#   'to_system': '30001847',
#   'real_investment': 20000000.0,
#   'profit': 20828825.15055629},
#  {'total_return': 104.1237113402062,
#   'adj_return': 104.1237113402062,
#   'type_id': '35',
#   'from_system': '30001939',
#   'to_system': '30000171',
#   'real_investment': 20000000.0,
#   'profit': 20824742.268041242},
#  {'total_return': 104.12329046744235,
#   'adj_return': 104.12329046744235,
#   'type_id': '20',
#   'from_system': '30002187',
#   'to_system': '30001847',
#   'real_investment': 20000000.0,
#   'profit': 20824658.09348847},
#  {'total_return': 104.10245943463617,
#   'adj_return': 104.10245943463617,
#   'type_id': '20',
#   'from_system': '30000142',
#   'to_system': '30001847',
#   'real_investment': 20000000.0,
#   'profit': 20820491.886927236},
#  {'total_return': 104.10245943463617,
#   'adj_return': 104.10245943463617,
#   'type_id': '20',
#   'from_system': '30002187',
#   'to_system': '30001847',
#   'real_investment': 20000000.0,
#   'profit': 20820491.886927236},
#  {'total_return': 104.05405405405406,
#   'adj_return': 104.05405405405406,
#   'type_id': '16272',
#   'from_system': '30000019',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 20810810.81081081},
#  {'total_return': 378.2608695652174,
#   'adj_return': 104.0085,
#   'type_id': '25599',
#   'from_system': '30000142',
#   'to_system': '30002910',
#   'real_investment': 5499300.0,
#   'profit': 20801700.0},
#  {'total_return': 104.00000000000003,
#   'adj_return': 104.00000000000003,
#   'type_id': '16273',
#   'from_system': '30000019',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20800000.000000004},
#  {'total_return': 104.00000000000003,
#   'adj_return': 104.00000000000003,
#   'type_id': '16273',
#   'from_system': '30000019',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20800000.000000004},
#  {'total_return': 104.0,
#   'adj_return': 104.0,
#   'type_id': '44',
#   'from_system': '30001324',
#   'to_system': '30001115',
#   'real_investment': 20000000.0,
#   'profit': 20800000.0},
#  {'total_return': 104.0,
#   'adj_return': 104.0,
#   'type_id': '44',
#   'from_system': '30001324',
#   'to_system': '30002320',
#   'real_investment': 20000000.0,
#   'profit': 20800000.0},
#  {'total_return': 185.71428571428572,
#   'adj_return': 104.0,
#   'type_id': '655',
#   'from_system': '30003412',
#   'to_system': '30003853',
#   'real_investment': 11200000.0,
#   'profit': 20800000.0},
#  {'total_return': 108.33333333333333,
#   'adj_return': 104.0,
#   'type_id': '655',
#   'from_system': '30002765',
#   'to_system': '30003853',
#   'real_investment': 19200000.0,
#   'profit': 20800000.0},
#  {'total_return': 103.99999999999997,
#   'adj_return': 103.99999999999997,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30000150',
#   'real_investment': 20000000.0,
#   'profit': 20799999.999999996},
#  {'total_return': 103.99999999999997,
#   'adj_return': 103.99999999999997,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30002700',
#   'real_investment': 20000000.0,
#   'profit': 20799999.999999996},
#  {'total_return': 103.95920815836834,
#   'adj_return': 103.95920815836834,
#   'type_id': '44',
#   'from_system': '30001277',
#   'to_system': '30001115',
#   'real_investment': 20000000.0,
#   'profit': 20791841.631673668},
#  {'total_return': 103.95920815836834,
#   'adj_return': 103.95920815836834,
#   'type_id': '44',
#   'from_system': '30001277',
#   'to_system': '30002320',
#   'real_investment': 20000000.0,
#   'profit': 20791841.631673668},
#  {'total_return': 2234.1113704568193,
#   'adj_return': 103.9520515,
#   'type_id': '21587',
#   'from_system': '30002659',
#   'to_system': '30004504',
#   'real_investment': 930589.7,
#   'profit': 20790410.3},
#  {'total_return': 103.79999999999998,
#   'adj_return': 103.79999999999998,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20759999.999999996},
#  {'total_return': 170.6687730384413,
#   'adj_return': 103.712,
#   'type_id': '17368',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 12153600.0,
#   'profit': 20742400.0},
#  {'total_return': 103.70967741935485,
#   'adj_return': 103.70967741935485,
#   'type_id': '19744',
#   'from_system': '30003563',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 20741935.48387097},
#  {'total_return': 146.5753424657534,
#   'adj_return': 103.61655299999998,
#   'type_id': '35',
#   'from_system': '30003563',
#   'to_system': '30005008',
#   'real_investment': 14138333.4,
#   'profit': 20723310.599999998},
#  {'total_return': 103.6072144288577,
#   'adj_return': 103.6072144288577,
#   'type_id': '16275',
#   'from_system': '30001015',
#   'to_system': '30005269',
#   'real_investment': 20000000.0,
#   'profit': 20721442.885771543},
#  {'total_return': 103.53333333333333,
#   'adj_return': 103.53333333333333,
#   'type_id': '16275',
#   'from_system': '30003897',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 20706666.666666668},
#  {'total_return': 103.46666666666667,
#   'adj_return': 103.46666666666667,
#   'type_id': '16275',
#   'from_system': '30003897',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 20693333.333333336},
#  {'total_return': 103.4587995930824,
#   'adj_return': 103.4587995930824,
#   'type_id': '655',
#   'from_system': '30000142',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 20691759.91861648},
#  {'total_return': 103.4,
#   'adj_return': 103.4,
#   'type_id': '35',
#   'from_system': '30001930',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 20680000.0},
#  {'total_return': 103.35536349771226,
#   'adj_return': 103.35536349771226,
#   'type_id': '655',
#   'from_system': '30000142',
#   'to_system': '30003853',
#   'real_investment': 20000000.0,
#   'profit': 20671072.69954245},
#  ...]

# %%
arb_stats = [arb for arb in arb_stats if arb["adj_return"] > 50]
len(arb_stats)
# Out:
# 5386

# %%
# We need to annotate each arbitrage with its distance

with bz2.open("mapSolarSystemJumps.csv.bz2", mode="r") as data_csv:
    route_contents = data_csv.read()

route_contents_f = StringIO(bytes.decode(route_contents, "utf-8"))
route_reader = csv.DictReader(route_contents_f)

G = nx.Graph()

for row in route_reader:
    G.add_edge(row["fromSolarSystemID"], row["toSolarSystemID"])

# %%
valid_arbitrages = []

for arb in arb_stats:
    if not nx.has_path(G, arb["from_system"], arb["to_system"]):
        # There are a lot of arbitrages in this list between
        # different universes and stuff like that
        break
    
    arb["jumps"] = len(nx.shortest_path(G, arb["from_system"], arb["to_system"]))
    
    # return per jump, considering compounding
    # i.e. a 100% return per jump with 2 jumps means you double your money
    # twice for a total of 300% return for the whole trip
    
    arb["adj_return_per_jump"] = 100*((1+(arb["adj_return"]/100))**(1/arb["jumps"])-1)
    
    valid_arbitrages.append(arb)
    
valid_arbitrages = sorted(valid_arbitrages, key=lambda a: a["adj_return_per_jump"], reverse=True)

# %%
len(valid_arbitrages)
# Out:
# 194

# %%
valid_arbitrages
# Out:
# [{'total_return': 1945.945945945946,
#   'adj_return': 1090.8288,
#   'type_id': '1824',
#   'from_system': '30003522',
#   'to_system': '30002187',
#   'real_investment': 11211296.0,
#   'profit': 218165760.0,
#   'jumps': 2,
#   'adj_return_per_jump': 245.08387386257274},
#  {'total_return': 1945.945945945946,
#   'adj_return': 1090.8288,
#   'type_id': '1824',
#   'from_system': '30003563',
#   'to_system': '30002187',
#   'real_investment': 11211296.0,
#   'profit': 218165760.0,
#   'jumps': 11,
#   'adj_return_per_jump': 25.257714892206874},
#  {'total_return': 1925.4180602006688,
#   'adj_return': 1090.26066,
#   'type_id': '1824',
#   'from_system': '30000142',
#   'to_system': '30002187',
#   'real_investment': 11324924.0,
#   'profit': 218052132.0,
#   'jumps': 12,
#   'adj_return_per_jump': 22.924044163799806},
#  {'total_return': 1924.0641711229948,
#   'adj_return': 1090.222784,
#   'type_id': '1824',
#   'from_system': '30000142',
#   'to_system': '30002187',
#   'real_investment': 11332499.2,
#   'profit': 218044556.8,
#   'jumps': 12,
#   'adj_return_per_jump': 22.923718189053254},
#  {'total_return': 1922.712090848364,
#   'adj_return': 1090.1849080000002,
#   'type_id': '1824',
#   'from_system': '30000142',
#   'to_system': '30002187',
#   'real_investment': 11340074.399999999,
#   'profit': 218036981.60000002,
#   'jumps': 12,
#   'adj_return_per_jump': 22.923392204797665},
#  {'total_return': 1920.013342228152,
#   'adj_return': 1090.109156,
#   'type_id': '1824',
#   'from_system': '30042715',
#   'to_system': '30002187',
#   'real_investment': 11355224.8,
#   'profit': 218021831.2,
#   'jumps': 15,
#   'adj_return_per_jump': 17.952129611648783},
#  {'total_return': 1399.009900990099,
#   'adj_return': 937.55376,
#   'type_id': '1824',
#   'from_system': '30002659',
#   'to_system': '30002187',
#   'real_investment': 13403104.0,
#   'profit': 187510752.0,
#   'jumps': 15,
#   'adj_return_per_jump': 16.878341561134146},
#  {'total_return': 3087.032943900642,
#   'adj_return': 1110.8992924,
#   'type_id': '1824',
#   'from_system': '30003018',
#   'to_system': '30002187',
#   'real_investment': 7197197.5200000005,
#   'profit': 222179858.48,
#   'jumps': 16,
#   'adj_return_per_jump': 16.867633947717685},
#  {'total_return': 3070.6806282722514,
#   'adj_return': 1110.7137,
#   'type_id': '1824',
#   'from_system': '30002801',
#   'to_system': '30002187',
#   'real_investment': 7234316.0,
#   'profit': 222142740.0,
#   'jumps': 16,
#   'adj_return_per_jump': 16.866514361264183},
#  {'total_return': 1650.2890173410406,
#   'adj_return': 1010.67,
#   'type_id': '1824',
#   'from_system': '30002505',
#   'to_system': '30002187',
#   'real_investment': 12248400.0,
#   'profit': 202134000.0,
#   'jumps': 16,
#   'adj_return_per_jump': 16.238250582591785},
#  {'total_return': 4225.714285714285,
#   'adj_return': 1120.37208,
#   'type_id': '1824',
#   'from_system': '30004967',
#   'to_system': '30002187',
#   'real_investment': 5302640.0,
#   'profit': 224074416.0,
#   'jumps': 17,
#   'adj_return_per_jump': 15.854073805437864},
#  {'total_return': 3937.3333333333335,
#   'adj_return': 1118.47828,
#   'type_id': '1824',
#   'from_system': '30002803',
#   'to_system': '30002187',
#   'real_investment': 5681400.0,
#   'profit': 223695656.0,
#   'jumps': 17,
#   'adj_return_per_jump': 15.843490493621726},
#  {'total_return': 2229.230769230769,
#   'adj_return': 1097.64648,
#   'type_id': '1824',
#   'from_system': '30001403',
#   'to_system': '30002187',
#   'real_investment': 9847760.0,
#   'profit': 219529296.0,
#   'jumps': 18,
#   'adj_return_per_jump': 14.79081697425373},
#  {'total_return': 1793.6835522201375,
#   'adj_return': 597.683359,
#   'type_id': '1824',
#   'from_system': '30002659',
#   'to_system': '30002187',
#   'real_investment': 6664312.2,
#   'profit': 119536671.8,
#   'jumps': 15,
#   'adj_return_per_jump': 13.82663336219263},
#  {'total_return': 1403.475670307845,
#   'adj_return': 584.597412,
#   'type_id': '1824',
#   'from_system': '30002659',
#   'to_system': '30002187',
#   'real_investment': 8330709.600000001,
#   'profit': 116919482.39999999,
#   'jumps': 15,
#   'adj_return_per_jump': 13.683041304895994},
#  {'total_return': 2756.603773584906,
#   'adj_return': 1106.73672,
#   'type_id': '1824',
#   'from_system': '30000160',
#   'to_system': '30002187',
#   'real_investment': 8029712.0,
#   'profit': 221347344.0,
#   'jumps': 20,
#   'adj_return_per_jump': 13.26106119327144},
#  {'total_return': 2229.230769230769,
#   'adj_return': 1097.64648,
#   'type_id': '1824',
#   'from_system': '30001425',
#   'to_system': '30002187',
#   'real_investment': 9847760.0,
#   'profit': 219529296.0,
#   'jumps': 20,
#   'adj_return_per_jump': 13.218248527948596},
#  {'total_return': 2227.4404304381246,
#   'adj_return': 664.836218,
#   'type_id': '1824',
#   'from_system': '30045344',
#   'to_system': '30002187',
#   'real_investment': 5969508.399999999,
#   'profit': 132967243.60000001,
#   'jumps': 19,
#   'adj_return_per_jump': 11.302162505171175},
#  {'total_return': 3340.1272438082256,
#   'adj_return': 1113.5468248,
#   'type_id': '1824',
#   'from_system': '30003327',
#   'to_system': '30002187',
#   'real_investment': 6667691.04,
#   'profit': 222709364.96,
#   'jumps': 24,
#   'adj_return_per_jump': 10.96065773842383},
#  {'total_return': 350.0,
#   'adj_return': 326.151,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30005060',
#   'real_investment': 18637200.0,
#   'profit': 65230200.0,
#   'jumps': 14,
#   'adj_return_per_jump': 10.9095191172206},
#  {'total_return': 9993.333333333334,
#   'adj_return': 224.85,
#   'type_id': '1824',
#   'from_system': '30005228',
#   'to_system': '30002187',
#   'real_investment': 450000.0,
#   'profit': 44970000.0,
#   'jumps': 14,
#   'adj_return_per_jump': 8.779930374950663},
#  {'total_return': 2247.2868217054265,
#   'adj_return': 1098.02524,
#   'type_id': '1824',
#   'from_system': '30003577',
#   'to_system': '30002187',
#   'real_investment': 9772008.0,
#   'profit': 219605048.0,
#   'jumps': 30,
#   'adj_return_per_jump': 8.629771396320084},
#  {'total_return': 2701.1100832562443,
#   'adj_return': 613.179,
#   'type_id': '1824',
#   'from_system': '30003570',
#   'to_system': '30002187',
#   'real_investment': 4540200.0,
#   'profit': 122635800.0,
#   'jumps': 25,
#   'adj_return_per_jump': 8.17525854608765},
#  {'total_return': 275.0,
#   'adj_return': 275.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003744',
#   'real_investment': 20000000.0,
#   'profit': 55000000.0,
#   'jumps': 23,
#   'adj_return_per_jump': 5.9151001499132105},
#  {'total_return': 414.5707376058041,
#   'adj_return': 414.5707376058041,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30004759',
#   'real_investment': 20000000.0,
#   'profit': 82914147.52116083,
#   'jumps': 29,
#   'adj_return_per_jump': 5.811431316079352},
#  {'total_return': 397.64207980652964,
#   'adj_return': 397.64207980652964,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30004759',
#   'real_investment': 20000000.0,
#   'profit': 79528415.96130593,
#   'jumps': 29,
#   'adj_return_per_jump': 5.689446628388128},
#  {'total_return': 280.0,
#   'adj_return': 280.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 56000000.0,
#   'jumps': 25,
#   'adj_return_per_jump': 5.485154635279299},
#  {'total_return': 278.75,
#   'adj_return': 278.75,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 55750000.0,
#   'jumps': 25,
#   'adj_return_per_jump': 5.471253047257663},
#  {'total_return': 433.4340991535671,
#   'adj_return': 433.4340991535671,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86686819.83071342,
#   'jumps': 32,
#   'adj_return_per_jump': 5.371041863180959},
#  {'total_return': 433.3131801692865,
#   'adj_return': 433.3131801692865,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86662636.03385732,
#   'jumps': 32,
#   'adj_return_per_jump': 5.37029535821425},
#  {'total_return': 433.2527206771463,
#   'adj_return': 433.2527206771463,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86650544.13542926,
#   'jumps': 32,
#   'adj_return_per_jump': 5.369922044241071},
#  {'total_return': 433.01088270858526,
#   'adj_return': 433.01088270858526,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86602176.54171705,
#   'jumps': 32,
#   'adj_return_per_jump': 5.3684283782026165},
#  {'total_return': 433.01088270858526,
#   'adj_return': 433.01088270858526,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86602176.54171705,
#   'jumps': 32,
#   'adj_return_per_jump': 5.3684283782026165},
#  {'total_return': 432.8899637243048,
#   'adj_return': 432.8899637243048,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86577992.74486095,
#   'jumps': 32,
#   'adj_return_per_jump': 5.367681298967719},
#  {'total_return': 432.6481257557437,
#   'adj_return': 432.6481257557437,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 86529625.15114874,
#   'jumps': 32,
#   'adj_return_per_jump': 5.366186647699833},
#  {'total_return': 414.3893591293833,
#   'adj_return': 342.7,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30004759',
#   'real_investment': 16540000.0,
#   'profit': 68540000.0,
#   'jumps': 29,
#   'adj_return_per_jump': 5.263944164501089},
#  {'total_return': 279.0,
#   'adj_return': 279.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 55800000.0,
#   'jumps': 26,
#   'adj_return_per_jump': 5.258058281500455},
#  {'total_return': 278.5,
#   'adj_return': 278.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 55700000.0,
#   'jumps': 26,
#   'adj_return_per_jump': 5.252714011309534},
#  {'total_return': 408.5247883917775,
#   'adj_return': 408.5247883917775,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 81704957.6783555,
#   'jumps': 32,
#   'adj_return_per_jump': 5.213690429592366},
#  {'total_return': 433.7363966142685,
#   'adj_return': 433.7363966142685,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 86747279.3228537,
#   'jumps': 33,
#   'adj_return_per_jump': 5.205926814186235},
#  {'total_return': 404.9576783555018,
#   'adj_return': 404.9576783555018,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 80991535.67110036,
#   'jumps': 32,
#   'adj_return_per_jump': 5.190548127188976},
#  {'total_return': 429.74607013301085,
#   'adj_return': 429.74607013301085,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 85949214.02660218,
#   'jumps': 33,
#   'adj_return_per_jump': 5.182005390806843},
#  {'total_return': 279.24999999999994,
#   'adj_return': 245.20830799999996,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002187',
#   'real_investment': 17561920.0,
#   'profit': 49041661.599999994,
#   'jumps': 25,
#   'adj_return_per_jump': 5.080770741121432},
#  {'total_return': 484.6666666666667,
#   'adj_return': 484.6666666666667,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 96933333.33333334,
#   'jumps': 36,
#   'adj_return_per_jump': 5.027495481559918},
#  {'total_return': 484.33333333333337,
#   'adj_return': 484.33333333333337,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 96866666.66666667,
#   'jumps': 36,
#   'adj_return_per_jump': 5.025831719141194},
#  {'total_return': 404.23216444981864,
#   'adj_return': 404.23216444981864,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 20000000.0,
#   'profit': 80846432.88996373,
#   'jumps': 33,
#   'adj_return_per_jump': 5.024793115423232},
#  {'total_return': 483.33333333333337,
#   'adj_return': 483.33333333333337,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 96666666.66666667,
#   'jumps': 36,
#   'adj_return_per_jump': 5.020834889806314},
#  {'total_return': 368.56106408706165,
#   'adj_return': 368.56106408706165,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 73712212.81741233,
#   'jumps': 32,
#   'adj_return_per_jump': 4.94492552075716},
#  {'total_return': 433.4945586457074,
#   'adj_return': 368.538,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 17003120.0,
#   'profit': 73707600.0,
#   'jumps': 32,
#   'adj_return_per_jump': 4.944764087915465},
#  {'total_return': 233.33333333333334,
#   'adj_return': 233.33333333333334,
#   'type_id': '16272',
#   'from_system': '30002391',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 46666666.66666667,
#   'jumps': 25,
#   'adj_return_per_jump': 4.93373945612916},
#  {'total_return': 429.86698911729144,
#   'adj_return': 354.789,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 16506920.0,
#   'profit': 70957800.0,
#   'jumps': 32,
#   'adj_return_per_jump': 4.847133393088088},
#  {'total_return': 429.62515114873037,
#   'adj_return': 347.4834,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 16176120.0,
#   'profit': 69496680.0,
#   'jumps': 32,
#   'adj_return_per_jump': 4.794087178226114},
#  {'total_return': 414.0,
#   'adj_return': 414.0,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 82800000.0,
#   'jumps': 36,
#   'adj_return_per_jump': 4.652347718056493},
#  {'total_return': 323.21644498186214,
#   'adj_return': 323.21644498186214,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 64643288.99637243,
#   'jumps': 32,
#   'adj_return_per_jump': 4.611656527801844},
#  {'total_return': 362.93833131801694,
#   'adj_return': 362.93833131801694,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003488',
#   'real_investment': 20000000.0,
#   'profit': 72587666.26360339,
#   'jumps': 34,
#   'adj_return_per_jump': 4.610242790959385},
#  {'total_return': 432.34582829504234,
#   'adj_return': 304.6326,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 14092080.0,
#   'profit': 60926520.0,
#   'jumps': 32,
#   'adj_return_per_jump': 4.46496237350793},
#  {'total_return': 448.7908101571947,
#   'adj_return': 448.7908101571947,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 89758162.03143895,
#   'jumps': 41,
#   'adj_return_per_jump': 4.239978452766824},
#  {'total_return': 345.0,
#   'adj_return': 345.0,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 69000000.0,
#   'jumps': 36,
#   'adj_return_per_jump': 4.234143064745655},
#  {'total_return': 445.3446191051996,
#   'adj_return': 445.3446191051996,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 89068923.82103992,
#   'jumps': 41,
#   'adj_return_per_jump': 4.22396382700303},
#  {'total_return': 323.21644498186214,
#   'adj_return': 323.21644498186214,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002138',
#   'real_investment': 20000000.0,
#   'profit': 64643288.99637243,
#   'jumps': 35,
#   'adj_return_per_jump': 4.208174173085366},
#  {'total_return': 349.57678355501815,
#   'adj_return': 289.1,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 16540000.0,
#   'profit': 57820000.0,
#   'jumps': 33,
#   'adj_return_per_jump': 4.203100987853015},
#  {'total_return': 365.9613059250302,
#   'adj_return': 269.66115,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 14737140.0,
#   'profit': 53932230.0,
#   'jumps': 32,
#   'adj_return_per_jump': 4.1702890101825485},
#  {'total_return': 454.7158403869408,
#   'adj_return': 454.7158403869408,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005199',
#   'real_investment': 20000000.0,
#   'profit': 90943168.07738815,
#   'jumps': 42,
#   'adj_return_per_jump': 4.163596343584297},
#  {'total_return': 450.6650544135429,
#   'adj_return': 450.6650544135429,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 90133010.8827086,
#   'jumps': 42,
#   'adj_return_per_jump': 4.145420772486119},
#  {'total_return': 450.60459492140274,
#   'adj_return': 450.60459492140274,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 90120918.98428054,
#   'jumps': 42,
#   'adj_return_per_jump': 4.1451485079089245},
#  {'total_return': 406.590084643289,
#   'adj_return': 406.590084643289,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002537',
#   'real_investment': 20000000.0,
#   'profit': 81318016.9286578,
#   'jumps': 40,
#   'adj_return_per_jump': 4.139722751475405},
#  {'total_return': 448.9721886336155,
#   'adj_return': 448.9721886336155,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 89794437.7267231,
#   'jumps': 42,
#   'adj_return_per_jump': 4.137786311246705},
#  {'total_return': 426.2998790810157,
#   'adj_return': 426.2998790810157,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 85259975.81620315,
#   'jumps': 41,
#   'adj_return_per_jump': 4.133641418443124},
#  {'total_return': 426.2394195888755,
#   'adj_return': 426.2394195888755,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 85247883.9177751,
#   'jumps': 41,
#   'adj_return_per_jump': 4.133349633578143},
#  {'total_return': 423.3373639661427,
#   'adj_return': 423.3373639661427,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 84667472.79322854,
#   'jumps': 41,
#   'adj_return_per_jump': 4.119305358965364},
#  {'total_return': 423.0955259975816,
#   'adj_return': 423.0955259975816,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 84619105.19951633,
#   'jumps': 41,
#   'adj_return_per_jump': 4.118131575289197},
#  {'total_return': 327.33333333333337,
#   'adj_return': 327.33333333333337,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 65466666.66666667,
#   'jumps': 36,
#   'adj_return_per_jump': 4.116916861118525},
#  {'total_return': 444.25634824667475,
#   'adj_return': 444.25634824667475,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 88851269.64933495,
#   'jumps': 42,
#   'adj_return_per_jump': 4.116397075170841},
#  {'total_return': 348.24667472793226,
#   'adj_return': 273.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 15713000.0,
#   'profit': 54720000.0,
#   'jumps': 33,
#   'adj_return_per_jump': 4.074818614146003},
#  {'total_return': 408.403869407497,
#   'adj_return': 408.403869407497,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 81680773.8814994,
#   'jumps': 41,
#   'adj_return_per_jump': 4.045812511656921},
#  {'total_return': 407.1946795646917,
#   'adj_return': 407.1946795646917,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 81438935.91293834,
#   'jumps': 41,
#   'adj_return_per_jump': 4.039769815499872},
#  {'total_return': 402.59975816203143,
#   'adj_return': 402.59975816203143,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 80519951.6324063,
#   'jumps': 41,
#   'adj_return_per_jump': 4.016678672396767},
#  {'total_return': 250.7255139056832,
#   'adj_return': 250.7255139056832,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002187',
#   'real_investment': 20000000.0,
#   'profit': 50145102.78113664,
#   'jumps': 32,
#   'adj_return_per_jump': 3.9992554243420075},
#  {'total_return': 377.44860943168084,
#   'adj_return': 377.44860943168084,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002537',
#   'real_investment': 20000000.0,
#   'profit': 75489721.88633616,
#   'jumps': 40,
#   'adj_return_per_jump': 3.985591324451865},
#  {'total_return': 415.84038694074974,
#   'adj_return': 415.84038694074974,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 83168077.38814995,
#   'jumps': 42,
#   'adj_return_per_jump': 3.983552590302386},
#  {'total_return': 467.3333333333333,
#   'adj_return': 307.3885,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 13155000.0,
#   'profit': 61477700.0,
#   'jumps': 36,
#   'adj_return_per_jump': 3.9787729242152015},
#  {'total_return': 371.584038694075,
#   'adj_return': 371.584038694075,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002537',
#   'real_investment': 20000000.0,
#   'profit': 74316807.738815,
#   'jumps': 40,
#   'adj_return_per_jump': 3.95346680189097},
#  {'total_return': 309.6735187424426,
#   'adj_return': 256.1,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 16540000.0,
#   'profit': 51220000.0,
#   'jumps': 33,
#   'adj_return_per_jump': 3.9236286157735334},
#  {'total_return': 450.78597339782345,
#   'adj_return': 383.2384,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 17003120.0,
#   'profit': 76647680.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.9170631262644084},
#  {'total_return': 393.47037484885124,
#   'adj_return': 393.47037484885124,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 78694074.96977025,
#   'jumps': 42,
#   'adj_return_per_jump': 3.8738470396685765},
#  {'total_return': 445.4050785973398,
#   'adj_return': 368.35,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 73670000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.8377761964824897},
#  {'total_return': 383.49455864570734,
#   'adj_return': 383.49455864570734,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 76698911.72914147,
#   'jumps': 42,
#   'adj_return_per_jump': 3.823350002830117},
#  {'total_return': 300.0,
#   'adj_return': 300.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30003574',
#   'real_investment': 20000000.0,
#   'profit': 60000000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.8178167666788942},
#  {'total_return': 256.50623885918003,
#   'adj_return': 256.50623885918003,
#   'type_id': '2679',
#   'from_system': '30002187',
#   'to_system': '30004504',
#   'real_investment': 20000000.0,
#   'profit': 51301247.771836005,
#   'jumps': 34,
#   'adj_return_per_jump': 3.8095404910570396},
#  {'total_return': 438.27085852478837,
#   'adj_return': 362.45,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 72490000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.8056739200839518},
#  {'total_return': 379.9274486094317,
#   'adj_return': 379.9274486094317,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 75985489.72188634,
#   'jumps': 42,
#   'adj_return_per_jump': 3.8050462818691733},
#  {'total_return': 417.0495767835551,
#   'adj_return': 417.0495767835551,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002526',
#   'real_investment': 20000000.0,
#   'profit': 83409915.35671102,
#   'jumps': 44,
#   'adj_return_per_jump': 3.8046098801750805},
#  {'total_return': 358.1015719467957,
#   'adj_return': 358.1015719467957,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 71620314.38935913,
#   'jumps': 41,
#   'adj_return_per_jump': 3.7817570364365505},
#  {'total_return': 406.8923821039903,
#   'adj_return': 406.8923821039903,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002526',
#   'real_investment': 20000000.0,
#   'profit': 81378476.42079806,
#   'jumps': 44,
#   'adj_return_per_jump': 3.75781388022729},
#  {'total_return': 448.24667472793226,
#   'adj_return': 370.7,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 16540000.0,
#   'profit': 74140000.0,
#   'jumps': 42,
#   'adj_return_per_jump': 3.757074734506083},
#  {'total_return': 369.16565900846433,
#   'adj_return': 237.5234,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003491',
#   'real_investment': 12868120.0,
#   'profit': 47504680.0,
#   'jumps': 33,
#   'adj_return_per_jump': 3.7550415619966193},
#  {'total_return': 426.360338573156,
#   'adj_return': 352.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 70520000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.751178326262572},
#  {'total_return': 262.5,
#   'adj_return': 262.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002507',
#   'real_investment': 20000000.0,
#   'profit': 52500000.0,
#   'jumps': 35,
#   'adj_return_per_jump': 3.7481183744900726},
#  {'total_return': 441.77750906892385,
#   'adj_return': 441.77750906892385,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 88355501.81378476,
#   'jumps': 46,
#   'adj_return_per_jump': 3.741525476981211},
#  {'total_return': 223.52941176470588,
#   'adj_return': 223.52941176470588,
#   'type_id': '649',
#   'from_system': '30004084',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44705882.35294118,
#   'jumps': 32,
#   'adj_return_per_jump': 3.7372677424005962},
#  {'total_return': 416.8681983071342,
#   'adj_return': 344.75,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 68950000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.706912825393527},
#  {'total_return': 352.17654171704964,
#   'adj_return': 352.17654171704964,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 70435308.34340993,
#   'jumps': 42,
#   'adj_return_per_jump': 3.657939585767833},
#  {'total_return': 438.33131801692866,
#   'adj_return': 438.33131801692866,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 87666263.60338573,
#   'jumps': 47,
#   'adj_return_per_jump': 3.646406122866419},
#  {'total_return': 401.69286577992744,
#   'adj_return': 332.2,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 66440000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.634535788614457},
#  {'total_return': 413.9056831922612,
#   'adj_return': 413.9056831922612,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001401',
#   'real_investment': 20000000.0,
#   'profit': 82781136.63845225,
#   'jumps': 46,
#   'adj_return_per_jump': 3.622481274945444},
#  {'total_return': 300.0,
#   'adj_return': 300.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 60000000.0,
#   'jumps': 39,
#   'adj_return_per_jump': 3.6185321150670857},
#  {'total_return': 233.61134278565473,
#   'adj_return': 233.61134278565473,
#   'type_id': '2679',
#   'from_system': '30002187',
#   'to_system': '30004504',
#   'real_investment': 20000000.0,
#   'profit': 46722268.55713095,
#   'jumps': 34,
#   'adj_return_per_jump': 3.607080371385507},
#  {'total_return': 233.33333333333331,
#   'adj_return': 233.33333333333331,
#   'type_id': '2679',
#   'from_system': '30002187',
#   'to_system': '30004504',
#   'real_investment': 20000000.0,
#   'profit': 46666666.666666664,
#   'jumps': 34,
#   'adj_return_per_jump': 3.604539954639363},
#  {'total_return': 257.5,
#   'adj_return': 257.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 51500000.0,
#   'jumps': 36,
#   'adj_return_per_jump': 3.6021525943951804},
#  {'total_return': 257.00000000000006,
#   'adj_return': 257.00000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 51400000.00000001,
#   'jumps': 36,
#   'adj_return_per_jump': 3.598124907759259},
#  {'total_return': 257.00000000000006,
#   'adj_return': 257.00000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 51400000.00000001,
#   'jumps': 36,
#   'adj_return_per_jump': 3.598124907759259},
#  {'total_return': 392.98669891172915,
#   'adj_return': 325.0,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 65000000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.59208143602765},
#  {'total_return': 381.6203143893591,
#   'adj_return': 315.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 63120000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.5355863311662405},
#  {'total_return': 257.99999999999994,
#   'adj_return': 257.99999999999994,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 51599999.99999999,
#   'jumps': 37,
#   'adj_return_per_jump': 3.507021487583506},
#  {'total_return': 257.75,
#   'adj_return': 257.75,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 51550000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.505067271186313},
#  {'total_return': 245.25,
#   'adj_return': 245.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 49050000.0,
#   'jumps': 36,
#   'adj_return_per_jump': 3.5018608446003796},
#  {'total_return': 402.5392986698912,
#   'adj_return': 402.5392986698912,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 80507859.73397824,
#   'jumps': 47,
#   'adj_return_per_jump': 3.4947956256025536},
#  {'total_return': 243.5,
#   'adj_return': 243.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 48700000.0,
#   'jumps': 36,
#   'adj_return_per_jump': 3.4872517812408965},
#  {'total_return': 407.01330108827085,
#   'adj_return': 336.6,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002510',
#   'real_investment': 16540000.0,
#   'profit': 67320000.0,
#   'jumps': 43,
#   'adj_return_per_jump': 3.48696922991536},
#  {'total_return': 400.12091898428054,
#   'adj_return': 400.12091898428054,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 80024183.7968561,
#   'jumps': 47,
#   'adj_return_per_jump': 3.4841737819081287},
#  {'total_return': 255.0,
#   'adj_return': 255.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 51000000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.483482759915968},
#  {'total_return': 398.91172914147523,
#   'adj_return': 398.91172914147523,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 79782345.82829505,
#   'jumps': 47,
#   'adj_return_per_jump': 3.4788439941900506},
#  {'total_return': 252.5,
#   'adj_return': 252.5,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 50500000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.463718834570373},
#  {'total_return': 438.2103990326481,
#   'adj_return': 375.8088,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002059',
#   'real_investment': 17151980.0,
#   'profit': 75161760.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.4491181363998535},
#  {'total_return': 250.0,
#   'adj_return': 250.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 50000000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.443818054564951},
#  {'total_return': 238.25000000000006,
#   'adj_return': 238.25000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 47650000.00000001,
#   'jumps': 36,
#   'adj_return_per_jump': 3.442986401722803},
#  {'total_return': 237.83783783783784,
#   'adj_return': 237.83783783783784,
#   'type_id': '16272',
#   'from_system': '30000019',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 47567567.56756757,
#   'jumps': 36,
#   'adj_return_per_jump': 3.439483029835899},
#  {'total_return': 235.25,
#   'adj_return': 235.25,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 47050000.0,
#   'jumps': 36,
#   'adj_return_per_jump': 3.4173910361553705},
#  {'total_return': 448.48851269649333,
#   'adj_return': 309.7015,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 13810900.0,
#   'profit': 61940300.0,
#   'jumps': 42,
#   'adj_return_per_jump': 3.41476771716851},
#  {'total_return': 233.33333333333334,
#   'adj_return': 233.33333333333334,
#   'type_id': '16272',
#   'from_system': '30000019',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 46666666.66666667,
#   'jumps': 36,
#   'adj_return_per_jump': 3.4009216003262788},
#  {'total_return': 442.92623941958885,
#   'adj_return': 365.5674,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 16506920.0,
#   'profit': 73113480.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.4001955404391326},
#  {'total_return': 365.17533252720676,
#   'adj_return': 365.17533252720676,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 73035066.50544135,
#   'jumps': 46,
#   'adj_return_per_jump': 3.398301798783665},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001376',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.393454561846787},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001393',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.393454561846787},
#  {'total_return': 232.23333333333335,
#   'adj_return': 232.23333333333335,
#   'type_id': '41489',
#   'from_system': '30003935',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 46446666.66666667,
#   'jumps': 36,
#   'adj_return_per_jump': 3.3914279444835937},
#  {'total_return': 441.41475211608224,
#   'adj_return': 361.03445,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 16358060.0,
#   'profit': 72206890.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.3782048650267127},
#  {'total_return': 249.09552523008566,
#   'adj_return': 249.09552523008566,
#   'type_id': '649',
#   'from_system': '30002751',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 49819105.04601713,
#   'jumps': 38,
#   'adj_return_per_jump': 3.3446520606694508},
#  {'total_return': 427.62998790810155,
#   'adj_return': 353.65,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 16540000.0,
#   'profit': 70730000.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.3419237000114066},
#  {'total_return': 351.0278113663845,
#   'adj_return': 351.0278113663845,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 70205562.27327691,
#   'jumps': 46,
#   'adj_return_per_jump': 3.3289012545042684},
#  {'total_return': 223.81513099793935,
#   'adj_return': 223.81513099793935,
#   'type_id': '649',
#   'from_system': '30000142',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44763026.19958787,
#   'jumps': 36,
#   'adj_return_per_jump': 3.3177454185983946},
#  {'total_return': 401.813784764208,
#   'adj_return': 280.7935,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002996',
#   'real_investment': 13976300.0,
#   'profit': 56158700.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.3149474621414488},
#  {'total_return': 254.83870967741933,
#   'adj_return': 254.83870967741933,
#   'type_id': '649',
#   'from_system': '30001382',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 50967741.935483865,
#   'jumps': 39,
#   'adj_return_per_jump': 3.3007224296053517},
#  {'total_return': 351.8742442563482,
#   'adj_return': 291.0,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 16540000.0,
#   'profit': 58200000.0,
#   'jumps': 42,
#   'adj_return_per_jump': 3.299791895527582},
#  {'total_return': 432.04353083434097,
#   'adj_return': 357.3,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 16540000.0,
#   'profit': 71460000.0,
#   'jumps': 47,
#   'adj_return_per_jump': 3.2872784174166503},
#  {'total_return': 250.0,
#   'adj_return': 250.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002661',
#   'real_investment': 20000000.0,
#   'profit': 50000000.0,
#   'jumps': 39,
#   'adj_return_per_jump': 3.2643611681090645},
#  {'total_return': 296.0701330108828,
#   'adj_return': 296.0701330108828,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000843',
#   'real_investment': 20000000.0,
#   'profit': 59214026.60217655,
#   'jumps': 43,
#   'adj_return_per_jump': 3.252761713829},
#  {'total_return': 335.8524788391778,
#   'adj_return': 335.8524788391778,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30022547',
#   'real_investment': 20000000.0,
#   'profit': 67170495.76783556,
#   'jumps': 46,
#   'adj_return_per_jump': 3.252050519528482},
#  {'total_return': 253.69774919614147,
#   'adj_return': 236.7,
#   'type_id': '649',
#   'from_system': '30000139',
#   'to_system': '30001868',
#   'real_investment': 18660000.0,
#   'profit': 47340000.0,
#   'jumps': 38,
#   'adj_return_per_jump': 3.2463765259258315},
#  {'total_return': 225.0,
#   'adj_return': 225.0,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002526',
#   'real_investment': 20000000.0,
#   'profit': 45000000.0,
#   'jumps': 37,
#   'adj_return_per_jump': 3.236835905539004},
#  {'total_return': 323.21644498186214,
#   'adj_return': 267.3,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 53460000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.2240746290099986},
#  {'total_return': 233.33333333333334,
#   'adj_return': 233.33333333333334,
#   'type_id': '16272',
#   'from_system': '30003897',
#   'to_system': '30003810',
#   'real_investment': 20000000.0,
#   'profit': 46666666.66666667,
#   'jumps': 38,
#   'adj_return_per_jump': 3.219075990895681},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001368',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0,
#   'jumps': 39,
#   'adj_return_per_jump': 3.2166627142777404},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30002739',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0,
#   'jumps': 39,
#   'adj_return_per_jump': 3.2166627142777404},
#  {'total_return': 266.0217654171705,
#   'adj_return': 266.0217654171705,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 53204353.083434105,
#   'jumps': 41,
#   'adj_return_per_jump': 3.2152980533413755},
#  {'total_return': 265.9008464328899,
#   'adj_return': 265.9008464328899,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 53180169.28657799,
#   'jumps': 41,
#   'adj_return_per_jump': 3.214466255497994},
#  {'total_return': 441.35429262394194,
#   'adj_return': 328.135,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 14869460.0,
#   'profit': 65627000.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.2119577491315},
#  {'total_return': 341.41475211608224,
#   'adj_return': 341.41475211608224,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 20000000.0,
#   'profit': 68282950.42321645,
#   'jumps': 47,
#   'adj_return_per_jump': 3.2096120491710067},
#  {'total_return': 442.98669891172915,
#   'adj_return': 327.15055,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 14770220.0,
#   'profit': 65430110.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.206792705038475},
#  {'total_return': 242.00000000000006,
#   'adj_return': 242.00000000000006,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002661',
#   'real_investment': 20000000.0,
#   'profit': 48400000.00000001,
#   'jumps': 39,
#   'adj_return_per_jump': 3.2031556813321815},
#  {'total_return': 324.7279322853688,
#   'adj_return': 324.7279322853688,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005230',
#   'real_investment': 20000000.0,
#   'profit': 64945586.45707376,
#   'jumps': 46,
#   'adj_return_per_jump': 3.1940323720518027},
#  {'total_return': 404.83675937122126,
#   'adj_return': 334.8,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 16540000.0,
#   'profit': 66960000.0,
#   'jumps': 47,
#   'adj_return_per_jump': 3.176461266200725},
#  {'total_return': 341.354292623942,
#   'adj_return': 341.354292623942,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003388',
#   'real_investment': 20000000.0,
#   'profit': 68270858.5247884,
#   'jumps': 48,
#   'adj_return_per_jump': 3.141411362560409},
#  {'total_return': 243.75,
#   'adj_return': 234.0,
#   'type_id': '649',
#   'from_system': '30002739',
#   'to_system': '30001868',
#   'real_investment': 19200000.0,
#   'profit': 46800000.0,
#   'jumps': 39,
#   'adj_return_per_jump': 3.1405389852222187},
#  {'total_return': 335.79201934703747,
#   'adj_return': 277.7,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002510',
#   'real_investment': 16540000.0,
#   'profit': 55540000.0,
#   'jumps': 43,
#   'adj_return_per_jump': 3.138787825339562},
#  {'total_return': 266.14268440145105,
#   'adj_return': 266.14268440145105,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 20000000.0,
#   'profit': 53228536.88029021,
#   'jumps': 42,
#   'adj_return_per_jump': 3.1383660024530524},
#  {'total_return': 223.52941176470588,
#   'adj_return': 223.52941176470588,
#   'type_id': '649',
#   'from_system': '30000153',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 44705882.35294118,
#   'jumps': 38,
#   'adj_return_per_jump': 3.138018485366212},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001366',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0,
#   'jumps': 40,
#   'adj_return_per_jump': 3.1349987533403345},
#  {'total_return': 230.49999999999994,
#   'adj_return': 230.49999999999994,
#   'type_id': '16273',
#   'from_system': '30003935',
#   'to_system': '30002659',
#   'real_investment': 20000000.0,
#   'profit': 46099999.99999999,
#   'jumps': 39,
#   'adj_return_per_jump': 3.112683340935418},
#  {'total_return': 335.3083434099154,
#   'adj_return': 335.3083434099154,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002320',
#   'real_investment': 20000000.0,
#   'profit': 67061668.681983076,
#   'jumps': 48,
#   'adj_return_per_jump': 3.1117768141670332},
#  {'total_return': 445.82829504232166,
#   'adj_return': 258.09,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000144',
#   'real_investment': 11578000.0,
#   'profit': 51618000.0,
#   'jumps': 42,
#   'adj_return_per_jump': 3.083769297177774},
#  {'total_return': 267.89297658862876,
#   'adj_return': 267.89297658862876,
#   'type_id': '649',
#   'from_system': '30005310',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 53578595.317725755,
#   'jumps': 43,
#   'adj_return_per_jump': 3.0757049955862703},
#  {'total_return': 266.78892964321443,
#   'adj_return': 266.78892964321443,
#   'type_id': '649',
#   'from_system': '30045305',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 53357785.928642884,
#   'jumps': 43,
#   'adj_return_per_jump': 3.068500705367594},
#  {'total_return': 244.80048367593713,
#   'adj_return': 244.80048367593713,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 20000000.0,
#   'profit': 48960096.735187426,
#   'jumps': 41,
#   'adj_return_per_jump': 3.0650483598376743},
#  {'total_return': 292.98669891172915,
#   'adj_return': 242.3,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000142',
#   'real_investment': 16540000.0,
#   'profit': 48460000.0,
#   'jumps': 41,
#   'adj_return_per_jump': 3.0467536852432753},
#  {'total_return': 340.0,
#   'adj_return': 297.5,
#   'type_id': '649',
#   'from_system': '30003416',
#   'to_system': '30001868',
#   'real_investment': 17500000.0,
#   'profit': 59500000.0,
#   'jumps': 46,
#   'adj_return_per_jump': 3.04550883405863},
#  {'total_return': 249.2063492063492,
#   'adj_return': 249.2063492063492,
#   'type_id': '649',
#   'from_system': '30002765',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 49841269.841269836,
#   'jumps': 42,
#   'adj_return_per_jump': 3.0221305190166303},
#  {'total_return': 471.42857142857144,
#   'adj_return': 247.17,
#   'type_id': '17429',
#   'from_system': '30003563',
#   'to_system': '30004472',
#   'real_investment': 10486000.0,
#   'profit': 49434000.0,
#   'jumps': 42,
#   'adj_return_per_jump': 3.0077858518541056},
#  {'total_return': 233.4343740527433,
#   'adj_return': 233.4343740527433,
#   'type_id': '649',
#   'from_system': '30002764',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 46686874.810548656,
#   'jumps': 41,
#   'adj_return_per_jump': 2.980821147523338},
#  {'total_return': 372.67230955259976,
#   'adj_return': 277.0718,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002659',
#   'real_investment': 14869460.0,
#   'profit': 55414360.0,
#   'jumps': 46,
#   'adj_return_per_jump': 2.9273894037135095},
#  {'total_return': 386.7593712212817,
#   'adj_return': 386.7593712212817,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 20000000.0,
#   'profit': 77351874.24425635,
#   'jumps': 55,
#   'adj_return_per_jump': 2.91925267685893},
#  {'total_return': 385.006045949214,
#   'adj_return': 385.006045949214,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 20000000.0,
#   'profit': 77001209.1898428,
#   'jumps': 55,
#   'adj_return_per_jump': 2.912500384970307},
#  {'total_return': 341.41475211608224,
#   'adj_return': 282.35,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30003409',
#   'real_investment': 16540000.0,
#   'profit': 56470000.0,
#   'jumps': 47,
#   'adj_return_per_jump': 2.894648816900136},
#  {'total_return': 338.3917775090689,
#   'adj_return': 279.85,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 16540000.0,
#   'profit': 55970000.0,
#   'jumps': 47,
#   'adj_return_per_jump': 2.8802883936287493},
#  {'total_return': 432.10399032648127,
#   'adj_return': 274.80215,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 12719260.0,
#   'profit': 54960430.0,
#   'jumps': 47,
#   'adj_return_per_jump': 2.851008559794521},
#  {'total_return': 400.06045949214024,
#   'adj_return': 272.28955,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30002053',
#   'real_investment': 13612420.0,
#   'profit': 54457910.0,
#   'jumps': 47,
#   'adj_return_per_jump': 2.8362901565481824},
#  {'total_return': 377.6299879081016,
#   'adj_return': 377.6299879081016,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000240',
#   'real_investment': 20000000.0,
#   'profit': 75525997.58162032,
#   'jumps': 56,
#   'adj_return_per_jump': 2.831610001169649},
#  {'total_return': 233.33333333333334,
#   'adj_return': 231.0,
#   'type_id': '649',
#   'from_system': '30005308',
#   'to_system': '30001868',
#   'real_investment': 19800000.0,
#   'profit': 46200000.0,
#   'jumps': 43,
#   'adj_return_per_jump': 2.8227045887006863},
#  {'total_return': 243.75,
#   'adj_return': 243.75,
#   'type_id': '649',
#   'from_system': '30001426',
#   'to_system': '30001868',
#   'real_investment': 20000000.0,
#   'profit': 48750000.0,
#   'jumps': 45,
#   'adj_return_per_jump': 2.7818675571417817},
#  {'total_return': 268.8029020556228,
#   'adj_return': 268.8029020556228,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005308',
#   'real_investment': 20000000.0,
#   'profit': 53760580.41112455,
#   'jumps': 48,
#   'adj_return_per_jump': 2.7562425516872713},
#  {'total_return': 386.69891172914146,
#   'adj_return': 319.8,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 16540000.0,
#   'profit': 63960000.0,
#   'jumps': 55,
#   'adj_return_per_jump': 2.64269449182315},
#  {'total_return': 378.89963724304715,
#   'adj_return': 313.35,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30005133',
#   'real_investment': 16540000.0,
#   'profit': 62670000.0,
#   'jumps': 55,
#   'adj_return_per_jump': 2.6138023716456127},
#  {'total_return': 353.4461910519952,
#   'adj_return': 353.4461910519952,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001115',
#   'real_investment': 20000000.0,
#   'profit': 70689238.21039903,
#   'jumps': 60,
#   'adj_return_per_jump': 2.551518626547633},
#  {'total_return': 414.20798065296253,
#   'adj_return': 294.93555,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30000240',
#   'real_investment': 14240940.0,
#   'profit': 58987110.0,
#   'jumps': 56,
#   'adj_return_per_jump': 2.483100051189302},
#  {'total_return': 292.98669891172915,
#   'adj_return': 292.98669891172915,
#   'type_id': '9848',
#   'from_system': '30001858',
#   'to_system': '30001274',
#   'real_investment': 20000000.0,
#   'profit': 58597339.78234583,
#   'jumps': 63,
#   'adj_return_per_jump': 2.196157997967507}]
